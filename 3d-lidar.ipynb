# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !mkdir -p lidar_project/OpenPCDet
# %cd lidar_project/OpenPCDet
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# %cd OpenPCDet
# Out:
# Cloning into 'OpenPCDet'...
# remote: Enumerating objects: 4169, done.
# remote: Total 4169 (delta 0), reused 0 (delta 0), pack-reused 4169 (from 1)
# Receiving objects: 100% (4169/4169), 4.20 MiB | 12.37 MiB/s, done.
# Resolving deltas: 100% (2452/2452), done.
# Updating files: 100% (352/352), done.
# /content/drive/MyDrive/lidar_project/OpenPCDet/OpenPCDet

# %%
# !pip install -q torch torchvision torchaudio
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet/data/kitti/
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet/data/kitti

# %%
# !wget -c https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# !wget -c https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# !wget -c https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# !wget -c https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip
# Out:
# --2025-07-22 12:48:45--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.208.9, 52.219.140.15, 3.5.136.245, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.208.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28750710812 (27G) [application/zip]
# Saving to: ‘data_object_velodyne.zip’
#
# data_object_velodyn 100%[===================>]  26.78G  30.2MB/s    in 16m 9s
#
# 2025-07-22 13:04:55 (28.3 MB/s) - ‘data_object_velodyne.zip’ saved [28750710812/28750710812]
#
# --2025-07-22 13:04:55--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 3.5.134.88, 3.5.139.184, 52.219.75.103, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|3.5.134.88|:443... connected.
# ...

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet/data/kitti/
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet/data/kitti

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet/
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
# !python setup.py develop
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
# ...

# %%
# %cd data/kitti/
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet/data/kitti

# %%
# !wget -c https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Out:
# --2025-07-22 15:32:53--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 3.5.134.75, 52.219.169.201, 52.219.171.181, ...
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|3.5.134.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28750710812 (27G) [application/zip]
# Saving to: ‘data_object_velodyne.zip’
#
# data_object_velodyn 100%[===================>]  26.78G  26.3MB/s    in 18m 25s
#
# 2025-07-22 15:51:18 (24.8 MB/s) - ‘data_object_velodyne.zip’ saved [28750710812/28750710812]

# %%
# !unzip -q data_object_velodyne.zip

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet/tools
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet/tools

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
# !python setup.py develop
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
# ...

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
# !pip install -q -r requirements.txt
# !python setup.py develop
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.7 MB/s eta 0:00:00
# ...

# %%
# Set arch flags to prevent IndexError
import os
os.environ["TORCH_CUDA_ARCH_LIST"] = "7.5;8.0;8.6;8.9"

# Go to your OpenPCDet repo
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet

# Install in development mode
# !python setup.py develop
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
# ...

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (103 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree -L 2
# Out:
# .
# ├── ImageSets
# │   ├── test.txt
# │   ├── train.txt
# │   └── val.txt
# ├── testing
# │   ├── calib
# │   ├── image_2
# │   └── velodyne
# └── training
#     ├── calib
#     ├── image_2
#     ├── label_2
#     └── velodyne
#
# 10 directories, 3 files

# %%
# %cd /content/drive/MyDrive/lidar_project/OpenPCDet/tools
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet/tools

# %%
# !tree -L 3
# Out:
# .
# ├── cfgs
# │   ├── argo2_models
# │   │   └── cbgs_voxel01_voxelnext.yaml
# │   ├── custom_models
# │   │   ├── pv_rcnn.yaml
# │   │   └── second.yaml
# │   ├── dataset_configs
# │   │   ├── argo2_dataset.yaml
# │   │   ├── custom_dataset.yaml
# │   │   ├── kitti_dataset.yaml
# │   │   ├── lyft_dataset.yaml
# │   │   ├── nuscenes_dataset.yaml
# │   │   ├── once_dataset.yaml
# │   │   ├── pandaset_dataset.yaml
# │   │   ├── waymo_dataset_multiframe.yaml
# │   │   └── waymo_dataset.yaml
# │   ├── kitti_models
# │   │   ├── CaDDN.yaml
# │   │   ├── PartA2_free.yaml
# │   │   ├── PartA2.yaml
# │   │   ├── pillarnet.yaml
# │   │   ├── pointpillar_newaugs.yaml
# │   │   ├── pointpillar_pyramid_aug.yaml
# │   │   ├── pointpillar.yaml
# │   │   ├── pointrcnn_iou.yaml
# │   │   ├── pointrcnn.yaml
# │   │   ├── pv_rcnn_plusplus_reproduced_by_community.yaml
# │   │   ├── pv_rcnn.yaml
# │   │   ├── second_iou.yaml
# │   │   ├── second_multihead.yaml
# │   │   ├── second.yaml
# ...

# %%
# !python train.py \
  --cfg_file cfgs/kitti_models/mvx_pv_rcnn.yaml \
  --workers 2 --extra_tag camera_lidar
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/train.py", line 7, in <module>
#     from test import repeat_eval_ckpt
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/test.py", line 14, in <module>
#     from eval_utils import eval_utils
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/eval_utils/eval_utils.py", line 8, in <module>
#     from pcdet.models import load_data_to_gpu
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/../pcdet/models/__init__.py", line 6, in <module>
#     from .detectors import build_detector
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/../pcdet/models/detectors/__init__.py", line 1, in <module>
#     from .detector3d_template import Detector3DTemplate
#   File "/content/drive/MyDrive/lidar_project/OpenPCDet/tools/../pcdet/models/detectors/detector3d_template.py", line 7, in <module>
#     from ...utils.spconv_utils import find_all_spconv_keys
# ...

# %%
# !nvcc --version
# !python --version
import torch; print(torch.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Python 3.11.13
# 2.6.0+cu124

# %%
ls
# Out:
# cfgs/    eval_utils/    process_tools/  scripts/  train.py      visual_utils/
# demo.py  _init_path.py  __pycache__/    test.py   train_utils/

# %%
cd ..
# Out:
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
cd ..
# Out:
# /content/drive/MyDrive/lidar_project

# %%
# !pip install torch==1.13.1+cu113 torchvision==0.14.1+cu113 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu113
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ERROR: Could not find a version that satisfies the requirement torch==1.13.1+cu113 (from versions: 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1)
# ERROR: No matching distribution found for torch==1.13.1+cu113

# %%
# !pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 570.7 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 77.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 83.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89990 sha256=99fe40da6680555e45acd6d0e62ef51f65e7cb8769bffcb08c89bc991b9eb5ff
#   Stored in directory: /root/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
# ...

# %%
# %cd drive/MyDrive/lidar_project/
# Out:
# /content/drive/MyDrive/lidar_project

# %%
# !rm -rf OpenPCDet

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# %cd OpenPCDet
# Out:
# Cloning into 'OpenPCDet'...
# remote: Enumerating objects: 4169, done.
# remote: Total 4169 (delta 0), reused 0 (delta 0), pack-reused 4169 (from 1)
# Receiving objects: 100% (4169/4169), 4.20 MiB | 8.23 MiB/s, done.
# Resolving deltas: 100% (2448/2448), done.
# Updating files: 100% (352/352), done.
# /content/drive/MyDrive/lidar_project/OpenPCDet

# %%
# !pip install -r requirements.txt

# %%
# !python setup.py develop
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
# ...

# %%
# !pip install openmim
# !pip install spconv-cu118
# !pip install cython scikit-image shapely pybind11
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 25.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf OpenPCDet

# %%
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 -f https://download.pytorch.org/whl/torch_stable.html

# STEP 2: Install spconv compatible with CUDA 11.6
# !pip install -q spconv-cu116

# STEP 3: Clone the OpenPCDet repo and build it
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# %cd OpenPCDet

# STEP 4: Install requirements and compile
# !pip install -q -r requirements.txt
# !python setup.py develop
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 632.1 kB/s eta 0:00:00
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.15.0
# ...

# %%
# !nvcc --version
# !python --version
import torch; print(torch.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Python 3.11.13
# 2.6.0+cu124
